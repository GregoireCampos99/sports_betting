# %%
# Import relevant packages
import duckdb, pandas as pd

# %% [markdown]
# # Define Variables

# %%
dic_leagues = {
    "England": 39,     # Premier League
    "France": 61,      # Ligue 1
    "Germany": 78,     # Bundesliga
    "Italy": 135,      # Serie A
    "Spain": 140,      # La Liga
}

# %% [markdown]
# # Define Functions

# %%
db_path = r"C:/Users/campo/Desktop/sports betting/warehouse.duckdb"
con = duckdb.connect(db_path, read_only=False) 

def get_table(table_name):
    query = f"""select * from {table_name} order by 1"""
    df_matches = con.execute(query).fetchdf()
    return df_matches

# %% [markdown]
# -----

# %% [markdown]
# # Gather tables

# %%
df_odds = get_table('warehouse.main.odds')
df_inj = get_table('warehouse.main.fact_injuries')
df_fixt = get_table('warehouse.main.fact_fixtures')
df_players = get_table('warehouse.main.fact_player_stats_match')

### Right now, we only have german odds for 2025. Let's restrict the other tables.
df_inj = df_inj[(df_inj.league_id == dic_leagues['Germany']) & (df_inj.season == 2025)]
df_fixt = df_fixt[(df_fixt.league_id == dic_leagues['Germany']) & (df_fixt.season == 2025)]
df_players = df_players[(df_players.league_id == dic_leagues['Germany']) & (df_players.season == 2025)]

# %% [markdown]
# ##### Injury table

# %%
df_inj.head(5)
# Out:
#        league_id  season  team_id  player_id      player_name status reason  \
# 14139         78    2025      186     474789  Abdoulie Ceesay   None   None
# 14140         78    2025      170     279993          A. Kade   None   None
# 14141         78    2025      175      48475         S. Hefti   None   None
# 14142         78    2025      162        973        M. Weiser   None   None
# 14143         78    2025      173       1144   L. Klostermann   None   None
#
#       start_date expected_return  fixture_id                 updated_ts
# 14139        NaT             NaT     1388320 2025-10-26 17:04:01.879562
# 14140        NaT             NaT     1388335 2025-10-26 17:04:01.880558
# 14141        NaT             NaT     1388339 2025-10-26 17:04:01.880558
# 14142        NaT             NaT     1388343 2025-10-26 17:04:01.880558
# 14143        NaT             NaT     1388341 2025-10-26 17:04:01.880558

# %% [markdown]
# ##### Fixtures table

# %%
df_fixt.head(5)
# Out:
#       fixture_id  league_id  season               round            date_utc  \
# 4578     1388308         78    2025  Regular Season - 1 2025-08-22 14:30:00
# 4579     1388309         78    2025  Regular Season - 1 2025-08-23 09:30:00
# 4580     1388310         78    2025  Regular Season - 1 2025-08-24 11:30:00
# 4581     1388311         78    2025  Regular Season - 1 2025-08-23 09:30:00
# 4582     1388312         78    2025  Regular Season - 1 2025-08-23 09:30:00
#
#       venue_id           venue_name status_short  home_team_id  away_team_id  \
# 4578      <NA>        Allianz Arena           FT           157           173
# 4579       699             BayArena           FT           168           167
# 4580     20471        Borussia-Park           FT           163           175
# 4581      <NA>   Deutsche Bank Park           FT           169           162
# 4582     12717  Europa-Park Stadion           FT           160           170
#
#       home_goals  away_goals                      referee  \
# 4578           6           0  Florian Badstubner, Germany
# 4579           1           2      Daniel Siebert, Germany
# 4580           0           0    Sascha Stegemann, Germany
# 4581           4           1         Harm Osmers, Germany
# 4582           1           3        Felix Zwayer, Germany
#
#                      updated_ts
# 4578 2025-10-26 17:03:39.176120
# 4579 2025-10-26 17:03:39.178193
# 4580 2025-10-26 17:03:39.185027
# 4581 2025-10-26 17:03:39.178193
# 4582 2025-10-26 17:03:39.177132

# %% [markdown]
# ##### Players stats table

# %%
display(df_players.head(5))
print(f"Columns = {df_players.columns}")
# Out:
#         fixture_id  league_id  season  team_id  player_id     player_name  \
# 159050     1388308         78    2025      173     513776    Yan Diomande
# 159051     1388308         78    2025      157     125171  Josip Stanišić
# 159052     1388308         78    2025      173      25158      David Raum
# 159053     1388308         78    2025      173         86     Loïs Openda
# 159054     1388308         78    2025      157        184      Harry Kane
#
#              team_name position  number  is_captain  ...  duels_total  \
# 159050      RB Leipzig        F      49       False  ...            7
# 159051  Bayern München        D      44       False  ...            4
# 159052      RB Leipzig        D      22        True  ...           10
# 159053      RB Leipzig        F      11       False  ...            3
# 159054  Bayern München        F       9       False  ...            8
#
#        duels_won  dribbles_attempts  dribbles_success  fouls_committed  \
# 159050         2                  2                 2                1
# 159051         3               <NA>              <NA>             <NA>
# 159052         5                  2                 1                2
# 159053         2                  1              <NA>             <NA>
# 159054         6                  3                 2             <NA>
#
#         fouls_drawn  yellow  red  offsides                 updated_ts
# 159050         <NA>       0    0      <NA> 2025-10-26 17:03:53.900437
# 159051            1       0    0      <NA> 2025-10-26 17:03:53.899414
# 159052            2       0    0      <NA> 2025-10-26 17:03:53.899414
# 159053            2       0    0      <NA> 2025-10-26 17:03:53.900437
# 159054            4       0    0         1 2025-10-26 17:03:53.899414
#
# [5 rows x 33 columns]
# Columns = Index(['fixture_id', 'league_id', 'season', 'team_id', 'player_id',
#        'player_name', 'team_name', 'position', 'number', 'is_captain',
#        'minutes', 'rating', 'shots_total', 'shots_on', 'goals', 'assists',
#        'saves', 'passes_total', 'passes_key', 'passes_accuracy', 'tackles',
#        'interceptions', 'blocks', 'duels_total', 'duels_won',
#        'dribbles_attempts', 'dribbles_success', 'fouls_committed',
#        'fouls_drawn', 'yellow', 'red', 'offsides', 'updated_ts'],
#       dtype='object')

# %% [markdown]
# ##### Odds table

# %%
df_odds.head(5)
# Out:
#                            event_id                  sport_key  \
# 0  15c8645215dcf291ab411c222a965c29  soccer_germany_bundesliga
# 1  15c8645215dcf291ab411c222a965c29  soccer_germany_bundesliga
# 2  15c8645215dcf291ab411c222a965c29  soccer_germany_bundesliga
# 3  15c8645215dcf291ab411c222a965c29  soccer_germany_bundesliga
# 4  15c8645215dcf291ab411c222a965c29  soccer_germany_bundesliga
#
#             sport_title                 league_key market           bookmaker  \
# 0  Bundesliga - Germany  soccer_germany_bundesliga    h2h        Winamax (FR)
# 1  Bundesliga - Germany  soccer_germany_bundesliga    h2h        Winamax (DE)
# 2  Bundesliga - Germany  soccer_germany_bundesliga    h2h  Parions Sport (FR)
# 3  Bundesliga - Germany  soccer_germany_bundesliga    h2h             Coolbet
# 4  Bundesliga - Germany  soccer_germany_bundesliga    h2h               1xBet
#
#                 last_update             commence_time  \
# 0 2025-10-26 12:04:07-04:00 2025-11-08 12:30:00-05:00
# 1 2025-10-26 12:03:42-04:00 2025-11-08 12:30:00-05:00
# 2 2025-10-26 12:04:21-04:00 2025-11-08 12:30:00-05:00
# 3 2025-10-26 12:03:16-04:00 2025-11-08 12:30:00-05:00
# 4 2025-10-26 12:04:06-04:00 2025-11-08 12:30:00-05:00
#
#                   home_team   away_team  price_home  price_draw  price_away  \
# 0  Borussia Monchengladbach  1. FC Köln        2.00        3.35        2.65
# 1  Borussia Monchengladbach  1. FC Köln        2.15        3.75        2.95
# 2  Borussia Monchengladbach  1. FC Köln        1.93        3.45        2.75
# 3  Borussia Monchengladbach  1. FC Köln        2.25        3.75        3.00
# 4  Borussia Monchengladbach  1. FC Köln        2.29        3.90        3.10
#
#                                          join_key  season
# 0  2025-11-08|Borussia Monchengladbach|1. FC Köln    2025
# 1  2025-11-08|Borussia Monchengladbach|1. FC Köln    2025
# 2  2025-11-08|Borussia Monchengladbach|1. FC Köln    2025
# 3  2025-11-08|Borussia Monchengladbach|1. FC Köln    2025
# 4  2025-11-08|Borussia Monchengladbach|1. FC Köln    2025

# %% [markdown]
# # Merge data

# %% [markdown]
# ##### The challenge is we have two different providers (TheOdds and API-Football).
# ##### Ugly, but as a first step we will use company names to map both dataframes.

# %%
# Football data
df = pd.merge(df_inj, df_fixt, on=['fixture_id', 'league_id', 'season'], how='inner', suffixes=['_injuries', '_fixtures'])
df = pd.merge(df, df_players, on=['league_id', 'season', 'team_id', 'fixture_id'], how='inner', suffixes=['_injuries', '_players'])

# %%
df_companies_apifootball = df[['team_name', 'team_id']].drop_duplicates().set_index('team_id')['team_name'].copy()
df_companies_odds = df_odds['home_team'].drop_duplicates().copy()

# %%
already_mapped = [comp for comp in df_companies_apifootball.to_list() if comp in df_companies_odds.to_list()]
in_api_not_in_odds = [comp for comp in df_companies_apifootball.to_list() if comp not in df_companies_odds.to_list()]
in_odds_not_in_api = [comp for comp in df_companies_odds.to_list() if comp not in df_companies_apifootball.to_list()]

print(f"already mapped: {already_mapped}")
print(f"in_api_not_in_odds: {in_api_not_in_odds}") # also contains team that got relegated.
print(f"in_odds_not_in_api: {in_odds_not_in_api}")
# Out:
# already mapped: ['FC St. Pauli', 'Werder Bremen', 'RB Leipzig', 'Bayer Leverkusen', 'VfB Stuttgart', 'FSV Mainz 05', '1. FC Heidenheim', 'Borussia Dortmund', 'VfL Wolfsburg', 'Eintracht Frankfurt', 'Union Berlin', 'SC Freiburg']
# in_api_not_in_odds: ['FC Augsburg', 'Hamburger SV', 'Borussia Mönchengladbach', '1.FC Köln', 'Bayern München', '1899 Hoffenheim']
# in_odds_not_in_api: ['Borussia Monchengladbach', '1. FC Köln', 'Augsburg', 'Bayern Munich', 'FC Bayern München']

# %% [markdown]
# ### mapping is annoying ... let's give API-Football another shot for odds.

# %%
from dotenv import load_dotenv
load_dotenv()
import os, requests, pandas as pd

API_KEY = os.getenv("API_FOOTBALL_KEY")
BASE = "https://v3.football.api-sports.io"
HEADERS = {"x-apisports-key": API_KEY}

resp = requests.get(f"{BASE}/odds", headers=HEADERS, timeout=30, params={'league':39, 'season':2025, "page":4})

j = resp.json()  # dict with keys: get, parameters, errors, results, response(list)
data = j.get("response", [])
# Flatten the common fields into a tidy DataFrame
df_odds = pd.json_normalize(data, sep="_")
display(df_odds)
## too weak. looks like we will need to go with TheOdds. we can't get more than the last game day.
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Conclusion:
#
# we will go with TheOdds for quotes and map to football data using team names and fixture date. it is not a big issue, because we are dealing with a group of 20 teams. mapping errors should not be an issue, as long as the names are consistent. looks like, at least in 2025, they are.
